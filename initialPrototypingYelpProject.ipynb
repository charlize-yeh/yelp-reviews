# %%
import numpy as np
from datascience import *

# These lines do some fancy plotting magic
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore')
from datetime import datetime

# %%
possible_scores = make_array(1,2,3,4,5)
scores = make_array()
for i in np.arange(500):  
  scores = np.append(scores, np.random.choice(possible_scores))

possible_quantities = make_array()
for j in np.arange(500):
  possible_quantities = np.append(possible_quantities, j)


quantities = make_array()
for k in np.arange(500):
  quantities = np.append(quantities, np.random.choice(possible_quantities))
  
reviews = Table().with_columns("Review", scores, "Number of Reviews", quantities)

# %%
reviews
# Out:
# Review | Number of Reviews
# 5      | 437
# 4      | 8
# 2      | 489
# 1      | 277
# 2      | 390
# 5      | 362
# 1      | 296
# 2      | 82
# 2      | 359
# 1      | 59
# ... (490 rows omitted)

# %%
mean_score = np.mean(reviews.column("Review"))
mean_score
# Out:
# 3.1160000000000001

# %%
total_num_reviews_amongst_reviewers = sum(reviews.column("Number of Reviews"))
total_num_reviews_amongst_reviewers
# Out:
# 128181.0

# %%
proportion_total_reviews = reviews.column("Number of Reviews") / total_num_reviews_amongst_reviewers
reviews = reviews.with_column("Proportion of Reviews", proportion_total_reviews)
reviews
# Out:
# Review | Number of Reviews | Proportion of Reviews
# 5      | 437               | 0.00340924
# 4      | 8                 | 6.24117e-05
# 2      | 489               | 0.00381492
# 1      | 277               | 0.00216101
# 2      | 390               | 0.00304257
# 5      | 362               | 0.00282413
# 1      | 296               | 0.00230923
# 2      | 82                | 0.00063972
# 2      | 359               | 0.00280073
# 1      | 59                | 0.000460287
# ... (490 rows omitted)

# %%
proportional_review = reviews.column("Proportion of Reviews") * reviews.column("Review")
reviews = reviews.with_column("Proportional Review", proportional_review)
reviews
# Out:
# Review | Number of Reviews | Proportion of Reviews | Proportional Review
# 5      | 437               | 0.00340924            | 0.0170462
# 4      | 8                 | 6.24117e-05           | 0.000249647
# 2      | 489               | 0.00381492            | 0.00762984
# 1      | 277               | 0.00216101            | 0.00216101
# 2      | 390               | 0.00304257            | 0.00608515
# 5      | 362               | 0.00282413            | 0.0141207
# 1      | 296               | 0.00230923            | 0.00230923
# 2      | 82                | 0.00063972            | 0.00127944
# 2      | 359               | 0.00280073            | 0.00560145
# 1      | 59                | 0.000460287           | 0.000460287
# ... (490 rows omitted)

# %%
weighted_review = sum(reviews.column("Proportional Review"))
weighted_review
# Out:
# 3.1521676379494648

# %%
num_of_reviews = reviews.column("Number of Reviews")
def find_percentile(val):
  return np.sum(val > num_of_reviews) / len(num_of_reviews)

number_of_review_percentiles = reviews.apply(find_percentile, "Number of Reviews")
reviews = reviews.with_column("num of review percentile",number_of_review_percentiles)
reviews
# Out:
# Review | Number of Reviews | Proportion of Reviews | Proportional Review | num of review percentile
# 5      | 437               | 0.00340924            | 0.0170462           | 0.866
# 4      | 8                 | 6.24117e-05           | 0.000249647         | 0.02
# 2      | 489               | 0.00381492            | 0.00762984          | 0.976
# 1      | 277               | 0.00216101            | 0.00216101          | 0.542
# 2      | 390               | 0.00304257            | 0.00608515          | 0.76
# 5      | 362               | 0.00282413            | 0.0141207           | 0.702
# 1      | 296               | 0.00230923            | 0.00230923          | 0.568
# 2      | 82                | 0.00063972            | 0.00127944          | 0.15
# 2      | 359               | 0.00280073            | 0.00560145          | 0.698
# 1      | 59                | 0.000460287           | 0.000460287         | 0.104
# ... (490 rows omitted)

# %%
sum_of_percentiles = sum(reviews.column("num of review percentile"))
sum_of_percentiles
# Out:
# 249.00800000000021

# %%
percentile_proportions = reviews.column("num of review percentile") / sum_of_percentiles
reviews = reviews.with_column("percentile_proportions",percentile_proportions)
reviews
# Out:
# Review | Number of Reviews | Proportion of Reviews | Proportional Review | num of review percentile | percentile_proportions
# 5      | 437               | 0.00340924            | 0.0170462           | 0.866                    | 0.0034778
# 4      | 8                 | 6.24117e-05           | 0.000249647         | 0.02                     | 8.03187e-05
# 2      | 489               | 0.00381492            | 0.00762984          | 0.976                    | 0.00391955
# 1      | 277               | 0.00216101            | 0.00216101          | 0.542                    | 0.00217664
# 2      | 390               | 0.00304257            | 0.00608515          | 0.76                     | 0.00305211
# 5      | 362               | 0.00282413            | 0.0141207           | 0.702                    | 0.00281919
# 1      | 296               | 0.00230923            | 0.00230923          | 0.568                    | 0.00228105
# 2      | 82                | 0.00063972            | 0.00127944          | 0.15                     | 0.00060239
# 2      | 359               | 0.00280073            | 0.00560145          | 0.698                    | 0.00280312
# 1      | 59                | 0.000460287           | 0.000460287         | 0.104                    | 0.000417657
# ... (490 rows omitted)

# %%
percentile_review = reviews.column("Review") * reviews.column("percentile_proportions")
reviews = reviews.with_column("percentile review",percentile_review)
reviews
# Out:
# Review | Number of Reviews | Proportion of Reviews | Proportional Review | num of review percentile | percentile_proportions | percentile review
# 5      | 437               | 0.00340924            | 0.0170462           | 0.866                    | 0.0034778              | 0.017389
# 4      | 8                 | 6.24117e-05           | 0.000249647         | 0.02                     | 8.03187e-05            | 0.000321275
# 2      | 489               | 0.00381492            | 0.00762984          | 0.976                    | 0.00391955             | 0.00783911
# 1      | 277               | 0.00216101            | 0.00216101          | 0.542                    | 0.00217664             | 0.00217664
# 2      | 390               | 0.00304257            | 0.00608515          | 0.76                     | 0.00305211             | 0.00610422
# 5      | 362               | 0.00282413            | 0.0141207           | 0.702                    | 0.00281919             | 0.0140959
# 1      | 296               | 0.00230923            | 0.00230923          | 0.568                    | 0.00228105             | 0.00228105
# 2      | 82                | 0.00063972            | 0.00127944          | 0.15                     | 0.00060239             | 0.00120478
# 2      | 359               | 0.00280073            | 0.00560145          | 0.698                    | 0.00280312             | 0.00560625
# 1      | 59                | 0.000460287           | 0.000460287         | 0.104                    | 0.000417657            | 0.000417657
# ... (490 rows omitted)

# %%
total_percentile_review = sum(reviews.column("percentile review"))
total_percentile_review
# Out:
# 3.1521718177729192

# %%
reviews
# Out:
# Review | Number of Reviews | Proportion of Reviews | Proportional Review | num of review percentile | percentile_proportions | percentile review
# 5      | 437               | 0.00340924            | 0.0170462           | 0.866                    | 0.0034778              | 0.017389
# 4      | 8                 | 6.24117e-05           | 0.000249647         | 0.02                     | 8.03187e-05            | 0.000321275
# 2      | 489               | 0.00381492            | 0.00762984          | 0.976                    | 0.00391955             | 0.00783911
# 1      | 277               | 0.00216101            | 0.00216101          | 0.542                    | 0.00217664             | 0.00217664
# 2      | 390               | 0.00304257            | 0.00608515          | 0.76                     | 0.00305211             | 0.00610422
# 5      | 362               | 0.00282413            | 0.0141207           | 0.702                    | 0.00281919             | 0.0140959
# 1      | 296               | 0.00230923            | 0.00230923          | 0.568                    | 0.00228105             | 0.00228105
# 2      | 82                | 0.00063972            | 0.00127944          | 0.15                     | 0.00060239             | 0.00120478
# 2      | 359               | 0.00280073            | 0.00560145          | 0.698                    | 0.00280312             | 0.00560625
# 1      | 59                | 0.000460287           | 0.000460287         | 0.104                    | 0.000417657            | 0.000417657
# ... (490 rows omitted)
